# %%
import pandas as pd

df = pd.read_csv('dataset/creator_posts.csv')
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  creator_id        creator_name  \
# 0               0           0           0          생방송 여자가 좋다
# 1               1           1           1                  전인
# 2               2           2           2                  써니
# 3               3           3           3  HR PLUS, 주간 경제 리포트
# 4               4           4           2                  써니
# ..            ...         ...         ...                 ...
# 239           239         239         174                  호지
# 240           240         240         175                 로공백
# 241           241         241         176              데이문프레스
# 242           242         242         176              데이문프레스
# 243           243         243         177                스페이스
#
#         membership_name                               membership_desc  \
# 0                  생방여보                       생방여의 지속적인 창작을 응원하는 앨라이들
# 1                   전인권                                    전인의 인권을 응원
# 2             뽀시래기 슈팅스타  여러분의 응원은 게임 개발을 비롯한 여러 창작의 여정을 이어갈 힘이 되어요 :3
# 3    HR PLUS 리포트 - 스탠다드                   HR PLUS 리포트 '스탠다드' 멤버십 입니다.
# 4               쪼꼬미 여행자   창작에 관한 이야기, 그리고 작은 선물로 선데이클럽 올인원팩을 드리고 있어요!
# ..                  ...                                           ...
# 239              모닝 리추얼                                   스트레칭 후 명상하기
# 240                말차라떼        매달 말차라떼 한 잔씩 후원해 주시면 글 쓸 때 큰 힘이 됩니다 :)
# 241         test 에세이 클럽                                    같이씁니다. 에세이
# 242         test 프롬프트박스                         조금은 어색한 그에게 안부를 남기세요.
# 243   오픈컨택 - 을 준비하는 사람들           외계문명과의 열린 대중적 공개적 만남을 준비하고 후원하는 멤버십
#
#      num_of_subs                                   creator_url  \
# 0            114     steadio.co/creator/yeojaisgood#membership
# 1              9          steadio.co/creator/jwieut#membership
# 2              1      steadio.co/creator/minisunday#membership
# 3             12  steadio.co/creator/economicreport#membership
# 4              5      steadio.co/creator/minisunday#membership
# ..           ...                                           ...
# 239            0            steadio.co/creator/hozi#membership
# 240            0      steadio.co/creator/logongback#membership
# 241            0         steadio.co/creator/daymoon#membership
# 242            0         steadio.co/creator/daymoon#membership
# 243            0     steadio.co/creator/opencontact#membership
#
#      total_subs_num  total_posts_num
# 0               563               35
# 1                29                6
# 2               126               43
# 3                91              140
# 4               126               43
# ..              ...              ...
# 239               0                1
# 240               0                0
# 241               0                0
# 242               0                0
# 243               0                0
#
# [244 rows x 10 columns]

# %% [markdown]
# ### 크리에이터가 몇개의 포스트를 작성했는지 크롤링하기

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# Chrome 브라우저 열기
driver = webdriver.Chrome()

# 웹 페이지로 이동
url = "https://steadio.co/creator/jwieut/community"
driver.get(url)

# 페이지 로딩을 기다림 (필요한 경우)
driver.implicitly_wait(10)  # 예: 최대 10초까지 대기

# 페이지의 HTML 가져오기
html_content = driver.page_source

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html_content, 'html.parser')

# 특정 요소 찾기
target_element = soup.find('div', class_='flex gap-[2px] font_title_bold_md content_secondary')

# 찾은 요소의 텍스트 출력
if target_element:
    print(target_element.span.text)
else:
    print("해당 요소를 찾을 수 없습니다.")

# 브라우저 닫기
driver.quit()
# Out:
# 2

# %%
url = "steadio.co/creator/yeojaisgood#membership"

# "https://"를 추가하고 "#" 이후의 부분을 제거하여 최종 URL 생성
final_url = "https://" + url.split("#")[0] + '/posts'

print(final_url)
# Out:
# https://steadio.co/creator/yeojaisgood/posts

# %%
# 함수 정의
def get_total_subs_num(url):
    url = "https://" + url.split("#")[0] + '/community'
    # Chrome 브라우저 열기
    driver = webdriver.Chrome()

    # 웹 페이지로 이동
    driver.get(url)

    # 페이지 로딩을 기다림 (필요한 경우)
    driver.implicitly_wait(10)  # 예: 최대 10초까지 대기

    # 페이지의 HTML 가져오기
    html_content = driver.page_source

    # BeautifulSoup을 사용하여 HTML 파싱
    soup = BeautifulSoup(html_content, 'html.parser')

    # strong class가 'font_label_bold_lg'인 요소 찾기
    strong_element = soup.find('div', class_='flex gap-[2px] font_title_bold_md content_secondary')

    

    # 찾은 요소의 텍스트 반환
    if strong_element:
        total_subs_num = strong_element.span.text
    else:
        total_subs_num = "해당 요소를 찾을 수 없습니다."

    # 브라우저 닫기
    driver.quit()

    return total_subs_num

# DataFrame의 'creator_url' 열에 함수 적용하여 'total_subs_num' 열에 결과 저장
df['total_community_posts_num'] = df['creator_url'].apply(get_total_subs_num)

# 결과 출력
print(df)
# Out:
#      Unnamed: 0.1  Unnamed: 0  creator_id        creator_name  \
# 0               0           0           0          생방송 여자가 좋다
# 1               1           1           1                  전인
# 2               2           2           2                  써니
# 3               3           3           3  HR PLUS, 주간 경제 리포트
# 4               4           4           2                  써니
# ..            ...         ...         ...                 ...
# 239           239         239         174                  호지
# 240           240         240         175                 로공백
# 241           241         241         176              데이문프레스
# 242           242         242         176              데이문프레스
# 243           243         243         177                스페이스
#
#         membership_name                               membership_desc  \
# 0                  생방여보                       생방여의 지속적인 창작을 응원하는 앨라이들
# 1                   전인권                                    전인의 인권을 응원
# 2             뽀시래기 슈팅스타  여러분의 응원은 게임 개발을 비롯한 여러 창작의 여정을 이어갈 힘이 되어요 :3
# 3    HR PLUS 리포트 - 스탠다드                   HR PLUS 리포트 '스탠다드' 멤버십 입니다.
# 4               쪼꼬미 여행자   창작에 관한 이야기, 그리고 작은 선물로 선데이클럽 올인원팩을 드리고 있어요!
# ..                  ...                                           ...
# 239              모닝 리추얼                                   스트레칭 후 명상하기
# 240                말차라떼        매달 말차라떼 한 잔씩 후원해 주시면 글 쓸 때 큰 힘이 됩니다 :)
# 241         test 에세이 클럽                                    같이씁니다. 에세이
# 242         test 프롬프트박스                         조금은 어색한 그에게 안부를 남기세요.
# 243   오픈컨택 - 을 준비하는 사람들           외계문명과의 열린 대중적 공개적 만남을 준비하고 후원하는 멤버십
#
#      num_of_subs                                   creator_url  \
# 0            114     steadio.co/creator/yeojaisgood#membership
# 1              9          steadio.co/creator/jwieut#membership
# 2              1      steadio.co/creator/minisunday#membership
# 3             12  steadio.co/creator/economicreport#membership
# 4              5      steadio.co/creator/minisunday#membership
# ..           ...                                           ...
# 239            0            steadio.co/creator/hozi#membership
# 240            0      steadio.co/creator/logongback#membership
# 241            0         steadio.co/creator/daymoon#membership
# 242            0         steadio.co/creator/daymoon#membership
# 243            0     steadio.co/creator/opencontact#membership
#
#      total_subs_num  total_posts_num total_community_posts_num
# 0               563               35                         4
# 1                29                6                         2
# 2               126               43                         0
# 3                91              140                         3
# 4               126               43                         0
# ..              ...              ...                       ...
# 239               0                1                         0
# 240               0                0                         0
# 241               0                0                         0
# 242               0                0                         0
# 243               0                0                         0
#
# [244 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'creator_id', 'creator_name',
#        'membership_name', 'membership_desc', 'num_of_subs', 'creator_url',
#        'total_subs_num', 'total_posts_num', 'total_community_posts_num'],
#       dtype='object')

# %%
df.to_csv("dataset/creator_community.csv")
